# %% [markdown]
# <a href="https://colab.research.google.com/github/Monikaa-11/fr/blob/main/note1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Github!')
# Out:
# Hello Github!
